# %%
# !pip install pymongo
# Out:
# ...
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#    ---------------------------------------- 0.0/910.9 kB ? eta -:--:--
#     -------------------------------------- 20.5/910.9 kB 682.7 kB/s eta 0:00:02
#    -------- ------------------------------- 204.8/910.9 kB 2.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 532.5/910.9 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 910.9/910.9 kB 5.8 MB/s eta 0:00:00
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymongo

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "#"


# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#create Database
database_name = 'student1'
student_database = client[database_name]

# %%
#create a collection
collection = 'student_database'

# %%
student_details_collections = student_database[collection]

# %%
# Document create
student_data = {
    "name" : "Sourav",
    "college" : "BIT Kolkata",
    "Address" : "Kolkata"
}

# %%
student_data = {
    "name" : "Abhinav",
    "college" : "BIT Kolkata",
    "Address" : "Kolkata"
}

# %%
student_details_collections.insert_one(student_data)
# Out:
# InsertOneResult(ObjectId('693714c684fa59e555d14b74'), acknowledged=True)

# %%
student_corsor = student_details_collections.find()

# %%
student_corsor.next()
# Out:
# {'_id': ObjectId('6937129084fa59e555d14b73'),
#  'name': 'Sourav',
#  'college': 'BIT Kolkata',
#  'Address': 'Kolkata'}

# %%
student_corsor.next()
# Out:
# {'_id': ObjectId('693714c684fa59e555d14b74'),
#  'name': 'Abhinav',
#  'college': 'BIT Kolkata',
#  'Address': 'Kolkata'}

# %%
for student_details in student_details_collections.find():
    print(student_details)
# Out:
# {'_id': ObjectId('6937129084fa59e555d14b73'), 'name': 'Sourav', 'college': 'BIT Kolkata', 'Address': 'Kolkata'}
# {'_id': ObjectId('693714c684fa59e555d14b74'), 'name': 'Abhinav', 'college': 'BIT Kolkata', 'Address': 'Kolkata'}
